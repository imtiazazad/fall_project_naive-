# %% [markdown]
# <a href="https://colab.research.google.com/github/imtiazazad/fall_project_naive-/blob/main/fall_project_naive_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Necessary Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
import plotly.express as px

from sklearn.metrics import confusion_matrix, classification_report, f1_score, accuracy_score, precision_score, recall_score,precision_recall_curve, auc

# %% [markdown]
# ## Dataset Loading and EDA

# %%
data = pd.read_csv("/content/FALL_23 DATASET.csv")

# %%
data.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
data.info()

print(f"Number of rows in dataset : {data.shape[0]}")
print(f"Number of columns in dataset : {data.shape[1]}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB
# Number of rows in dataset : 100000
# Number of columns in dataset : 9

# %%
smoking_history_counts = data['smoking_history'].value_counts().reset_index()

smoking_history_counts.columns = ['Smoking History', 'Count']

fig = px.bar(smoking_history_counts, x='Smoking History', y='Count',
             labels={'Smoking History': 'Smoking History', 'Count': 'Count'},
             title='Distribution of Smoking History',
             color='Smoking History', color_discrete_sequence=px.colors.qualitative.Set2)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="09e17b4f-c959-455e-9ba3-1e2ec2203462" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09e17b4f-c959-455e-9ba3-1e2ec2203462")) {                    Plotly.newPlot(                        "09e17b4f-c959-455e-9ba3-1e2ec2203462",                        [{"alignmentgroup":"True","hovertemplate":"Smoking History=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No Info","marker":{"color":"rgb(102,194,165)","pattern":{"shape":""}},"name":"No Info","offsetgroup":"No Info","orientation":"v","showlegend":true,"textposition":"auto","x":["No Info"],"xaxis":"x","y":[35816],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Smoking History=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"never","marker":{"color":"rgb(252,141,98)","pattern":{"shape":""}},"name":"never","offsetgroup":"never","orientation":"v","showlegend":true,"textposition":"auto","x":["never"],"xaxis":"x","y":[35095],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Smoking History=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"former","marker":{"color":"rgb(141,160,203)","pattern":{"shape":""}},"name":"former","offsetgroup":"former","orientation":"v","showlegend":true,"textposition":"auto","x":["former"],"xaxis":"x","y":[9352],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Smoking History=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"current","marker":{"color":"rgb(231,138,195)","pattern":{"shape":""}},"name":"current","offsetgroup":"current","orientation":"v","showlegend":true,"textposition":"auto","x":["current"],"xaxis":"x","y":[9286],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Smoking History=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"not current","marker":{"color":"rgb(166,216,84)","pattern":{"shape":""}},"name":"not current","offsetgroup":"not current","orientation":"v","showlegend":true,"textposition":"auto","x":["not current"],"xaxis":"x","y":[6447],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Smoking History=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ever","marker":{"color":"rgb(255,217,47)","pattern":{"shape":""}},"name":"ever","offsetgroup":"ever","orientation":"v","showlegend":true,"textposition":"auto","x":["ever"],"xaxis":"x","y":[4004],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777 ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['age'], kde=True, color='brown', bins=13)  # Using Seaborn for the histogram with KDE

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['HbA1c_level'], kde=True, color='green', bins=5)  # Using Seaborn for the histogram with KDE

# Add labels and title
plt.xlabel('HbA1c level')
plt.ylabel('Frequency')
plt.title('HbA1c level Distribution')

# Show the plot
plt.show()

# %% [markdown]
# ## Dataset Processing

# %%
le = LabelEncoder()

# %%
data['gender'] = le.fit_transform(data['gender'])

# %%
data['gender']
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        1
#         ..
# 99995    0
# 99996    0
# 99997    1
# 99998    0
# 99999    0
# Name: gender, Length: 100000, dtype: int64

# %%
data['smoking_history'] = le.fit_transform(data['smoking_history'])

# %%
minmax = MinMaxScaler()

# %%
data['bmi_scaled'] = minmax.fit_transform(np.array(data['bmi']).reshape(-1,1))

# %%
data['HbA1c_level_scaled'] = minmax.fit_transform(np.array(data['HbA1c_level']).reshape(-1,1))

# %%
data['age_scaled'] = minmax.fit_transform(np.array(data['age']).reshape(-1,1))

# %%
data
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0           0  80.0             0              1                4  25.19
# 1           0  54.0             0              0                0  27.32
# 2           1  28.0             0              0                4  27.32
# 3           0  36.0             0              0                1  23.45
# 4           1  76.0             1              1                1  20.14
# ...       ...   ...           ...            ...              ...    ...
# 99995       0  80.0             0              0                0  27.32
# 99996       0   2.0             0              0                0  17.37
# 99997       1  66.0             0              0                3  27.83
# 99998       0  24.0             0              0                4  35.42
# 99999       0  57.0             0              0                1  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes  bmi_scaled  \
# 0              6.6                  140         0    0.177171
# 1              6.6                   80         0    0.202031
# 2              5.7                  158         0    0.202031
# 3              5.0                  155         0    0.156863
# 4              4.8                  155         0    0.118231
# ...            ...                  ...       ...         ...
# 99995          6.2                   90         0    0.202031
# 99996          6.5                  100         0    0.085901
# 99997          5.7                  155         0    0.207983
# 99998          4.0                  100         0    0.296569
# 99999          6.6                   90         0    0.144958
#
#        HbA1c_level_scaled  age_scaled
# 0                0.563636    1.000000
# 1                0.563636    0.674675
# 2                0.400000    0.349349
# 3                0.272727    0.449449
# 4                0.236364    0.949950
# ...                   ...         ...
# 99995            0.490909    1.000000
# 99996            0.545455    0.024024
# 99997            0.400000    0.824825
# 99998            0.090909    0.299299
# 99999            0.563636    0.712212
#
# [100000 rows x 12 columns]

# %%
data['blood_glucose_level_scaled'] = minmax.fit_transform(np.array(data['blood_glucose_level']).reshape(-1,1))

# %%
data
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0           0  80.0             0              1                4  25.19
# 1           0  54.0             0              0                0  27.32
# 2           1  28.0             0              0                4  27.32
# 3           0  36.0             0              0                1  23.45
# 4           1  76.0             1              1                1  20.14
# ...       ...   ...           ...            ...              ...    ...
# 99995       0  80.0             0              0                0  27.32
# 99996       0   2.0             0              0                0  17.37
# 99997       1  66.0             0              0                3  27.83
# 99998       0  24.0             0              0                4  35.42
# 99999       0  57.0             0              0                1  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes  bmi_scaled  \
# 0              6.6                  140         0    0.177171
# 1              6.6                   80         0    0.202031
# 2              5.7                  158         0    0.202031
# 3              5.0                  155         0    0.156863
# 4              4.8                  155         0    0.118231
# ...            ...                  ...       ...         ...
# 99995          6.2                   90         0    0.202031
# 99996          6.5                  100         0    0.085901
# 99997          5.7                  155         0    0.207983
# 99998          4.0                  100         0    0.296569
# 99999          6.6                   90         0    0.144958
#
#        HbA1c_level_scaled  age_scaled  blood_glucose_level_scaled
# 0                0.563636    1.000000                    0.272727
# 1                0.563636    0.674675                    0.000000
# 2                0.400000    0.349349                    0.354545
# 3                0.272727    0.449449                    0.340909
# 4                0.236364    0.949950                    0.340909
# ...                   ...         ...                         ...
# 99995            0.490909    1.000000                    0.045455
# 99996            0.545455    0.024024                    0.090909
# 99997            0.400000    0.824825                    0.340909
# 99998            0.090909    0.299299                    0.090909
# 99999            0.563636    0.712212                    0.045455
#
# [100000 rows x 13 columns]

# %%
data_final = data[['age_scaled','gender','heart_disease','hypertension','smoking_history','diabetes','bmi_scaled','HbA1c_level_scaled','blood_glucose_level_scaled']]

# %%
data_final
# Out:
#        age_scaled  gender  heart_disease  hypertension  smoking_history  \
# 0        1.000000       0              1             0                4
# 1        0.674675       0              0             0                0
# 2        0.349349       1              0             0                4
# 3        0.449449       0              0             0                1
# 4        0.949950       1              1             1                1
# ...           ...     ...            ...           ...              ...
# 99995    1.000000       0              0             0                0
# 99996    0.024024       0              0             0                0
# 99997    0.824825       1              0             0                3
# 99998    0.299299       0              0             0                4
# 99999    0.712212       0              0             0                1
#
#        diabetes  bmi_scaled  HbA1c_level_scaled  blood_glucose_level_scaled
# 0             0    0.177171            0.563636                    0.272727
# 1             0    0.202031            0.563636                    0.000000
# 2             0    0.202031            0.400000                    0.354545
# 3             0    0.156863            0.272727                    0.340909
# 4             0    0.118231            0.236364                    0.340909
# ...         ...         ...                 ...                         ...
# 99995         0    0.202031            0.490909                    0.045455
# 99996         0    0.085901            0.545455                    0.090909
# 99997         0    0.207983            0.400000                    0.340909
# 99998         0    0.296569            0.090909                    0.090909
# 99999         0    0.144958            0.563636                    0.045455
#
# [100000 rows x 9 columns]

# %%
# data_final['diabetes'].unique()

# %% [markdown]
# ## Train-test split

# %%
X_train, X_test, y_train, y_test = train_test_split(data_final.drop(columns = ['diabetes']), data_final['diabetes'], test_size= 0.3, random_state= 42, stratify= data_final['diabetes'])

# %%
# Calculate value counts for each class
class_counts = y_train.value_counts()

# Create a bar plot using Seaborn
plt.figure(figsize=(4, 4))
sns.barplot(x=class_counts.index, y=class_counts.values, palette='cubehelix')
plt.title('Class Distribution in y_train')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
class_counts = y_test.value_counts()

# Create a bar plot using Seaborn
plt.figure(figsize=(4, 4))
sns.barplot(x=class_counts.index, y=class_counts.values, palette='cubehelix')
plt.title('Class Distribution in y_test')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Model training and Evaluation

# %%
naive = GaussianNB()

# %%
naive.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
preds = naive.predict(X_test)

# %%
accuracy = accuracy_score(y_test,preds)
print(f"Accuracy is {accuracy}")
# Out:
# Accuracy is 0.9034666666666666

# %%
f1 = f1_score(y_test,preds)
print(f"F1 score is {f1}")
# Out:
# F1 score is 0.533204384268214

# %%
precision = precision_score(y_test,preds)
print(f"Precision score is {precision}")
# Out:
# Precision score is 0.4526546250684182

# %%
recall = recall_score(y_test,preds)

print(f"Recall score is {recall}")
# Out:
# Recall score is 0.6486274509803922

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt


fpr, tpr, thresholds = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR) or Recall')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='best')
plt.show()

# %%
cm = confusion_matrix(y_test, preds)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
print(classification_report(y_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95     27450
#            1       0.45      0.65      0.53      2550
#
#     accuracy                           0.90     30000
#    macro avg       0.71      0.79      0.74     30000
# weighted avg       0.92      0.90      0.91     30000
